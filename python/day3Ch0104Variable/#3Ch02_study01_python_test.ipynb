# %% [markdown]
# 안녕하세요
#
# 여러분
# #안녕하세요
# ##안녕하세요
# ###안녕하세요
# ####안녕하세요
# ######안녕하세요

# %%
print("안녕하세요!")
# Out:
# 안녕하세요!

# %%
print("안녕하세요!")
# Out:
# 안녕하세요!

# %%
print("안녕하세요!")
# Out:
# 안녕하세요!

# %% [markdown]
# print사용해서 계산하는 방법과 print 없이 계산 하는 방법이 있음

# %%
print(2+3)
2+3
# Out:
# 5
# 5

# %% [markdown]
# 마지막 값만 나옴

# %%
2+4
2+3
# Out:
# 5
